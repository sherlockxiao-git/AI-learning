# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 读入数据

# %%
path="ex6data2.txt"
data=pd.read_csv(path,header=None,names=["X1","X2","Y"])
data.head()
# Out:
#          X1        X2  Y
# 0  0.107143  0.603070  1
# 1  0.093318  0.649854  1
# 2  0.097926  0.705409  1
# 3  0.155530  0.784357  1
# 4  0.210829  0.866228  1

# %%
positive = data[data['Y']==1]
negative = data[data['Y']==0]

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(positive['X1'], positive['X2'], s=50, c='b', marker='o', label='y=1')
ax.scatter(negative['X1'], negative['X2'], s=50, c='r', marker='x', label='y=0')
ax.legend()
ax.set_xlabel('X1')
ax.set_ylabel('X2')
plt.show()

# %%
X = data[["X1","X2"]].values

# %%
Y = data["Y"].values

# %% [markdown]
# ### 导入sk库

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.svm import SVC

# %%
from sklearn.pipeline import Pipeline

# %% [markdown]
# # pipeline拼接

# %% [markdown]
# # C=1

# %%
rbf_kernel_svm_clf=Pipeline([
    ("scalar",StandardScaler()),
    ("linear_svc",SVC(C=0.01,kernel="rbf",gamma=0.1))
])

# %%
rbf_kernel_svm_clf.fit(X,Y)
# Out:
# Pipeline(memory=None,
#          steps=[('scalar',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('linear_svc',
#                  SVC(C=0.01, break_ties=False, cache_size=200,
#                      class_weight=None, coef0=0.0,
#                      decision_function_shape='ovr', degree=3, gamma=0.1,
#                      kernel='rbf', max_iter=-1, probability=False,
#                      random_state=None, shrinking=True, tol=0.001,
#                      verbose=False))],
#          verbose=False)

# %%
rbf_kernel_svm_clf.score(X,Y)
# Out:
# 0.5561993047508691

# %%
data['SVM Confidence'] = rbf_kernel_svm_clf.decision_function(X)

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.scatter(data['X1'], data['X2'], s=50, c=data['SVM Confidence'], cmap='RdBu')
ax.set_title('SVM (C=0.01) gamma=0.1 Decision Confidence')
# Out:
# Text(0.5, 1.0, 'SVM (C=0.01) gamma=0.1 Decision Confidence')

# %% [markdown]
# # C=100

# %%
rbf_2 = Pipeline([
    ("scalar",StandardScaler()),
    ("linear_svc",SVC(C=100,kernel="rbf",gamma=0.1))
])

# %%
rbf_2.fit(X,Y)
# Out:
# Pipeline(memory=None,
#          steps=[('scalar',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('linear_svc',
#                  SVC(C=100, break_ties=False, cache_size=200, class_weight=None,
#                      coef0=0.0, decision_function_shape='ovr', degree=3,
#                      gamma=0.1, kernel='rbf', max_iter=-1, probability=False,
#                      random_state=None, shrinking=True, tol=0.001,
#                      verbose=False))],
#          verbose=False)

# %%
rbf_2.score(X,Y)
# Out:
# 0.8528389339513326

# %%
data['SVM Confidence'] = rbf_2.decision_function(X)

# %%
data['SVM Confidence'] = rbf_2.decision_function(X)

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.scatter(data['X1'], data['X2'], s=50, c=data['SVM Confidence'], cmap='RdBu')
ax.set_title('SVM (C=100) gamma=0.1 Decision Confidence')
# Out:
# Text(0.5, 1.0, 'SVM (C=100) gamma=0.1 Decision Confidence')

# %%
rbf_3 = Pipeline([
    ("scalar",StandardScaler()),
    ("linear_svc",SVC(C=0.01,kernel="rbf",gamma=5))
])

# %%
rbf_3.fit(X,Y)
# Out:
# Pipeline(memory=None,
#          steps=[('scalar',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('linear_svc',
#                  SVC(C=0.01, break_ties=False, cache_size=200,
#                      class_weight=None, coef0=0.0,
#                      decision_function_shape='ovr', degree=3, gamma=5,
#                      kernel='rbf', max_iter=-1, probability=False,
#                      random_state=None, shrinking=True, tol=0.001,
#                      verbose=False))],
#          verbose=False)

# %%
rbf_3.score(X,Y)
# Out:
# 0.5561993047508691

# %%
data['SVM Confidence'] = rbf_3.decision_function(X)

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.scatter(data['X1'], data['X2'], s=50, c=data['SVM Confidence'], cmap='RdBu')
ax.set_title('SVM (C=0.01 gamma=5 Decision Confidence')
# Out:
# Text(0.5, 1.0, 'SVM (C=0.01 gamma=5 Decision Confidence')

# %%
rbf_4 = Pipeline([
    ("scalar",StandardScaler()),
    ("svc",SVC(C = 100,kernel="rbf",gamma=5))
])

# %%
rbf_4.fit(X,Y)
# Out:
# Pipeline(memory=None,
#          steps=[('scalar',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('svc',
#                  SVC(C=100, break_ties=False, cache_size=200, class_weight=None,
#                      coef0=0.0, decision_function_shape='ovr', degree=3,
#                      gamma=5, kernel='rbf', max_iter=-1, probability=False,
#                      random_state=None, shrinking=True, tol=0.001,
#                      verbose=False))],
#          verbose=False)

# %%
rbf_4.score(X,Y)
# Out:
# 0.9988412514484357

# %%
data['SVM Confidence'] = rbf_4.decision_function(X)

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.scatter(data['X1'], data['X2'], s=50, c=data['SVM Confidence'], cmap='RdBu')
ax.set_title('SVM (C=100) gamma=5 Decision Confidence')
# Out:
# Text(0.5, 1.0, 'SVM (C=100) gamma=5 Decision Confidence')

# %%
rbf_4["svc"].support_
# Out:
# array([194, 226, 239, 255, 265, 274, 275, 277, 294, 405, 546, 549, 550,
#        572, 635, 639, 645, 648, 649, 652, 674, 678, 681, 754, 756, 759,
#        767, 773, 791, 803, 807, 811, 812,  23,  30,  88, 109, 110, 158,
#        160, 168, 169, 328, 329, 340, 351, 368, 409, 427, 435, 530, 576,
#        617, 619, 620, 699, 711, 715, 723, 724, 741, 743, 744, 749, 814,
#        833, 834, 853])

# %%
rbf_4["svc"].n_support_
# Out:
# array([33, 35])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-9afd95bd951d> in <module>
# ----> 1 rbf_4["svc"].support_vetors_
#
# AttributeError: 'SVC' object has no attribute 'support_vetors_'

# %% [markdown]
# # 自行解决

# %%
from sklearn.preprocessing import StandardScaler

standardScaler = StandardScaler()
standardScaler.fit(X)
X_standard = standardScaler.transform(X)

# %%
from sklearn.svm import LinearSVC

svc = LinearSVC(C=1)
svc.fit(X_standard, Y)
# Out:
# LinearSVC(C=1, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
def plot_svc_decision_boundary(model, axis):
    
    x0, x1 = np.meshgrid(
        np.linspace(axis[0], axis[1], int((axis[1]-axis[0])*100)).reshape(-1, 1),
        np.linspace(axis[2], axis[3], int((axis[3]-axis[2])*100)).reshape(-1, 1),
    )
    X_new = np.c_[x0.ravel(), x1.ravel()]

    y_predict = model.predict(X_new)
    zz = y_predict.reshape(x0.shape)

    from matplotlib.colors import ListedColormap
    custom_cmap = ListedColormap(['#EF9A9A','#FFF59D','#90CAF9'])
    
    plt.contourf(x0, x1, zz, cmap=custom_cmap)
    
    w = model.coef_[0]
    b = model.intercept_[0]
    
    # w0*x0 + w1*x1 + b = 0
    # => x1 = -w0/w1 * x0 - b/w1
    plot_x = np.linspace(axis[0], axis[1], 200)
    up_y = -w[0]/w[1] * plot_x - b/w[1] + 1/w[1]
    down_y = -w[0]/w[1] * plot_x - b/w[1] - 1/w[1]
    
    up_index = (up_y >= axis[2]) & (up_y <= axis[3])
    down_index = (down_y >= axis[2]) & (down_y <= axis[3])
    plt.plot(plot_x[up_index], up_y[up_index], color='black')
    plt.plot(plot_x[down_index], down_y[down_index], color='black')

# %%
plot_svc_decision_boundary(svc, axis=[-3, 3, -3, 3])
plt.scatter(X_standard[Y==0,0], X_standard[Y==0,1])
plt.scatter(X_standard[Y==1,0], X_standard[Y==1,1])
plt.show()

# %%
svc2 = LinearSVC(C=100)
svc2.fit(X_standard, Y)
# Out:
# c:\users\wxl\.virtualenvs\testvirtual-ee4p-oil\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC(C=100, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
plot_svc_decision_boundary(svc2, axis=[-3, 3, -3, 3])
plt.scatter(X_standard[Y==0,0], X_standard[Y==0,1])
plt.scatter(X_standard[Y==1,0], X_standard[Y==1,1])
plt.show()
